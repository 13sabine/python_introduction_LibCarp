# %%
ls
# Out:
#  Datentr„ger in Laufwerk C: ist WINDOWS
#  Volumeseriennummer: 4466-E47B
#
#  Verzeichnis von C:\Users\zbiw
#
# 16.05.2019  09:26    <DIR>          .
# 16.05.2019  09:26    <DIR>          ..
# 16.05.2019  08:40    <DIR>          .cisco
# 16.05.2019  09:26    <DIR>          .ipynb_checkpoints
# 16.05.2019  08:59    <DIR>          .ipython
# 15.05.2019  08:50    <DIR>          .RapidMiner
# 16.05.2019  08:39    <DIR>          3D Objects
# 16.05.2019  08:39    <DIR>          AppData
# 15.05.2019  08:55    <DIR>          bg
# 16.05.2019  08:39    <DIR>          Contacts
# 16.05.2019  08:40    <DIR>          Desktop
# 16.05.2019  08:39    <DIR>          Documents
# 16.05.2019  08:39    <DIR>          Downloads
# 16.05.2019  08:39    <DIR>          Favorites
# 16.05.2019  08:39    <DIR>          IntelGraphicsProfiles
# 16.05.2019  08:39    <DIR>          Links
# 16.05.2019  08:39    <DIR>          Music
# 16.05.2019  08:49    <DIR>          OneDrive
# ...

# %%
import urllib.request

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/OpenAPC/openapc-de/master/data/fuberlin/APC_FU_Berlin_2015.csv"
apc_file = "openAPC.csv"

# %%
urllib.request.urlretrieve(url, apc_file)
# Out:
# ('openAPC.csv', <http.client.HTTPMessage at 0x1582f821518>)

# %%
ls
# Out:
#  Datentr„ger in Laufwerk C: ist WINDOWS
#  Volumeseriennummer: 4466-E47B
#
#  Verzeichnis von C:\Users\zbiw
#
# 16.05.2019  09:40    <DIR>          .
# 16.05.2019  09:40    <DIR>          ..
# 16.05.2019  08:40    <DIR>          .cisco
# 16.05.2019  09:26    <DIR>          .ipynb_checkpoints
# 16.05.2019  08:59    <DIR>          .ipython
# 16.05.2019  09:31    <DIR>          .matplotlib
# 15.05.2019  08:50    <DIR>          .RapidMiner
# 16.05.2019  08:39    <DIR>          3D Objects
# 16.05.2019  08:39    <DIR>          AppData
# 15.05.2019  08:55    <DIR>          bg
# 16.05.2019  08:39    <DIR>          Contacts
# 16.05.2019  08:40    <DIR>          Desktop
# 16.05.2019  08:39    <DIR>          Documents
# 16.05.2019  08:39    <DIR>          Downloads
# 16.05.2019  08:39    <DIR>          Favorites
# 16.05.2019  08:39    <DIR>          IntelGraphicsProfiles
# 16.05.2019  08:39    <DIR>          Links
# 16.05.2019  08:39    <DIR>          Music
# ...

# %%
for line in open(apc_file):
    print(line.strip())
    split_line = line.split(",")
    print(split_line)
    print("xxxxxxxxxxxxxx")
# Out:
# "institution","period","euro","doi","is_hybrid","publisher","journal_full_title","issn","issn_print","issn_electronic","license_ref","indexed_in_crossref","pmid","pmcid","ut","url","doaj"
# ['"institution"', '"period"', '"euro"', '"doi"', '"is_hybrid"', '"publisher"', '"journal_full_title"', '"issn"', '"issn_print"', '"issn_electronic"', '"license_ref"', '"indexed_in_crossref"', '"pmid"', '"pmcid"', '"ut"', '"url"', '"doaj"\n']
# xxxxxxxxxxxxxx
# "FU Berlin",2015,2000,"10.1038/npjqi.2015.10",FALSE,"Springer Nature","npj Quantum Information","2056-6387",NA,"2056-6387",NA,TRUE,NA,NA,NA,NA,TRUE
# ['"FU Berlin"', '2015', '2000', '"10.1038/npjqi.2015.10"', 'FALSE', '"Springer Nature"', '"npj Quantum Information"', '"2056-6387"', 'NA', '"2056-6387"', 'NA', 'TRUE', 'NA', 'NA', 'NA', 'NA', 'TRUE\n']
# xxxxxxxxxxxxxx
# ...

# %%
for line in open(apc_file):
    #print(line.strip())
    split_line = line.split(",")
    #print(split_line)
    print(split_line[2])
    print("xxxxxxxxxxxxxx")
# Out:
# "euro"
# xxxxxxxxxxxxxx
# 2000
# xxxxxxxxxxxxxx
# 1503.12
# xxxxxxxxxxxxxx
# 2000
# xxxxxxxxxxxxxx
# 2000
# xxxxxxxxxxxxxx
# 1805
# xxxxxxxxxxxxxx
# 1191.32
# xxxxxxxxxxxxxx
# 1236.83
# xxxxxxxxxxxxxx
# 1499.08
# xxxxxxxxxxxxxx
# 1160.25
# xxxxxxxxxxxxxx
# 1191.21
# xxxxxxxxxxxxxx
# 1142.4
# xxxxxxxxxxxxxx
# 1298.29
# xxxxxxxxxxxxxx
# 2000
# xxxxxxxxxxxxxx
# 1165
# xxxxxxxxxxxxxx
# 1386.35
# xxxxxxxxxxxxxx
# 2000
# xxxxxxxxxxxxxx
# 892.5
# xxxxxxxxxxxxxx
# 1535.87
# xxxxxxxxxxxxxx
# 223.93
# xxxxxxxxxxxxxx
# 1178.42
# xxxxxxxxxxxxxx
# 1285.52
# xxxxxxxxxxxxxx
# 1392.3
# xxxxxxxxxxxxxx
# 1509.22
# xxxxxxxxxxxxxx
# 2000
# xxxxxxxxxxxxxx
# 1249.5
# xxxxxxxxxxxxxx
# 1625
# xxxxxxxxxxxxxx
# 1800
# xxxxxxxxxxxxxx
# 1550.33
# xxxxxxxxxxxxxx
# 2000
# xxxxxxxxxxxxxx
# 2000
# xxxxxxxxxxxxxx
# 1429.79
# xxxxxxxxxxxxxx
# 1410.07
# xxxxxxxxxxxxxx
# 2000
# xxxxxxxxxxxxxx
# 1785
# xxxxxxxxxxxxxx
# 1202.03
# xxxxxxxxxxxxxx
# 1243.27
# xxxxxxxxxxxxxx
# 1687
# xxxxxxxxxxxxxx
# 1687
# xxxxxxxxxxxxxx
# ...

# %%
for line in open(apc_file):
    split_line = line.split(",")
    print("Preis: " + split_line[2])
# Out:
# Preis: "euro"
# Preis: 2000
# Preis: 1503.12
# Preis: 2000
# Preis: 2000
# Preis: 1805
# Preis: 1191.32
# Preis: 1236.83
# Preis: 1499.08
# Preis: 1160.25
# Preis: 1191.21
# Preis: 1142.4
# Preis: 1298.29
# Preis: 2000
# Preis: 1165
# Preis: 1386.35
# Preis: 2000
# Preis: 892.5
# Preis: 1535.87
# Preis: 223.93
# Preis: 1178.42
# Preis: 1285.52
# Preis: 1392.3
# Preis: 1509.22
# Preis: 2000
# Preis: 1249.5
# Preis: 1625
# Preis: 1800
# Preis: 1550.33
# Preis: 2000
# Preis: 2000
# Preis: 1429.79
# Preis: 1410.07
# Preis: 2000
# Preis: 1785
# Preis: 1202.03
# Preis: 1243.27
# Preis: 1687
# Preis: 1687
# Preis: 895.15
# Preis: 853.84
# Preis: 1904
# Preis: 435.46
# Preis: 1150
# Preis: 770
# Preis: 1299.92
# Preis: 2000
# Preis: 1202.03
# Preis: 430.5
# Preis: 1600
# Preis: 1280
# Preis: 1513.7
# Preis: 1904
# Preis: 1072.55
# Preis: 981.75
# Preis: 1969.45
# Preis: 1130.5
# Preis: 1731.45
# Preis: 1600
# Preis: 219.84
# Preis: 1386.35
# Preis: 2000

# %%
for line in open(apc_file):
    split_line = line.split(",")
    print("Preis: " + split_line[2] + " €")
# Out:
# Preis: "euro" €
# Preis: 2000 €
# Preis: 1503.12 €
# Preis: 2000 €
# Preis: 2000 €
# Preis: 1805 €
# Preis: 1191.32 €
# Preis: 1236.83 €
# Preis: 1499.08 €
# Preis: 1160.25 €
# Preis: 1191.21 €
# Preis: 1142.4 €
# Preis: 1298.29 €
# Preis: 2000 €
# Preis: 1165 €
# Preis: 1386.35 €
# Preis: 2000 €
# Preis: 892.5 €
# Preis: 1535.87 €
# Preis: 223.93 €
# Preis: 1178.42 €
# Preis: 1285.52 €
# Preis: 1392.3 €
# Preis: 1509.22 €
# Preis: 2000 €
# Preis: 1249.5 €
# Preis: 1625 €
# Preis: 1800 €
# Preis: 1550.33 €
# Preis: 2000 €
# Preis: 2000 €
# Preis: 1429.79 €
# Preis: 1410.07 €
# Preis: 2000 €
# Preis: 1785 €
# Preis: 1202.03 €
# Preis: 1243.27 €
# Preis: 1687 €
# Preis: 1687 €
# Preis: 895.15 €
# Preis: 853.84 €
# Preis: 1904 €
# Preis: 435.46 €
# Preis: 1150 €
# Preis: 770 €
# Preis: 1299.92 €
# Preis: 2000 €
# Preis: 1202.03 €
# Preis: 430.5 €
# Preis: 1600 €
# Preis: 1280 €
# Preis: 1513.7 €
# Preis: 1904 €
# Preis: 1072.55 €
# Preis: 981.75 €
# Preis: 1969.45 €
# Preis: 1130.5 €
# ...

# %%
APCs = pd.read_csv(apc_file)

# %%
APCs
# Out:
#    institution  period     euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00          10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12      10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00   10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00      10.1186/s13099-015-0075-z      False
# 5    FU Berlin    2015  1191.32   10.1371/journal.pone.0139894      False
# 6    FU Berlin    2015  1236.83   10.1371/journal.pone.0142240      False
# 7    FU Berlin    2015  1499.08       10.3389/fcimb.2015.00067      False
# 8    FU Berlin    2015  1160.25       10.5194/acp-15-6897-2015      False
# 9    FU Berlin    2015  1191.21   10.1371/journal.pone.0140050      False
# 10   FU Berlin    2015  1142.40       10.3389/fpsyg.2015.01137      False
# 11   FU Berlin    2015  1298.29       10.3389/fpsyg.2015.01661      False
# ...

# %%
APCs
# Out:
#    institution  period     euro                            doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00          10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12      10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00             10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00   10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00      10.1186/s13099-015-0075-z      False
# 5    FU Berlin    2015  1191.32   10.1371/journal.pone.0139894      False
# 6    FU Berlin    2015  1236.83   10.1371/journal.pone.0142240      False
# 7    FU Berlin    2015  1499.08       10.3389/fcimb.2015.00067      False
# 8    FU Berlin    2015  1160.25       10.5194/acp-15-6897-2015      False
# 9    FU Berlin    2015  1191.21   10.1371/journal.pone.0140050      False
# 10   FU Berlin    2015  1142.40       10.3389/fpsyg.2015.01137      False
# 11   FU Berlin    2015  1298.29       10.3389/fpsyg.2015.01661      False
# ...

# %%
type(APCs)
# Out:
# pandas.core.frame.DataFrame

# %%
APCs.shape
# Out:
# (61, 17)

# %%
APCs.columns
# Out:
# Index(['institution', 'period', 'euro', 'doi', 'is_hybrid', 'publisher',
#        'journal_full_title', 'issn', 'issn_print', 'issn_electronic',
#        'license_ref', 'indexed_in_crossref', 'pmid', 'pmcid', 'ut', 'url',
#        'doaj'],
#       dtype='object')

# %%
APCs["doaj"]
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27    False
# 28     True
# 29     True
#       ...
# 31     True
# 32     True
# 33    False
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41    False
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# 53     True
# 54     True
# 55     True
# 56     True
# 57     True
# 58     True
# 59     True
# 60     True
# Name: doaj, Length: 61, dtype: bool

# %%
APCs["euro"] * 3
# Out:
# 0     6000.00
# 1     4509.36
# 2     6000.00
# 3     6000.00
# 4     5415.00
# 5     3573.96
# 6     3710.49
# 7     4497.24
# 8     3480.75
# 9     3573.63
# 10    3427.20
# 11    3894.87
# 12    6000.00
# 13    3495.00
# 14    4159.05
# 15    6000.00
# 16    2677.50
# 17    4607.61
# 18     671.79
# 19    3535.26
# 20    3856.56
# 21    4176.90
# 22    4527.66
# 23    6000.00
# 24    3748.50
# 25    4875.00
# 26    5400.00
# 27    4650.99
# 28    6000.00
# 29    6000.00
#        ...
# 31    4230.21
# 32    6000.00
# 33    5355.00
# 34    3606.09
# 35    3729.81
# 36    5061.00
# 37    5061.00
# 38    2685.45
# 39    2561.52
# 40    5712.00
# 41    1306.38
# 42    3450.00
# 43    2310.00
# 44    3899.76
# 45    6000.00
# 46    3606.09
# 47    1291.50
# 48    4800.00
# 49    3840.00
# 50    4541.10
# 51    5712.00
# 52    3217.65
# 53    2945.25
# 54    5908.35
# 55    3391.50
# 56    5194.35
# 57    4800.00
# 58     659.52
# 59    4159.05
# 60    6000.00
# ...

# %%
APCs["euro"] [1] * 3
# Out:
# 4509.36

# %%
APCs["euro"] [[2, 5, 7]] * 3
# Out:
# 2    6000.00
# 5    3573.96
# 7    4497.24
# Name: euro, dtype: float64

# %%
APCs["euro"] >= 2000
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29     True
#       ...
# 31    False
# 32     True
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45     True
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# 60     True
# Name: euro, Length: 61, dtype: bool

# %%
APCs[APCs["euro"] < 2000]
# Out:
#    institution  period     euro                            doi  is_hybrid  \
# 1    FU Berlin    2015  1503.12      10.1103/PhysRevX.5.041008      False
# 4    FU Berlin    2015  1805.00      10.1186/s13099-015-0075-z      False
# 5    FU Berlin    2015  1191.32   10.1371/journal.pone.0139894      False
# 6    FU Berlin    2015  1236.83   10.1371/journal.pone.0142240      False
# 7    FU Berlin    2015  1499.08       10.3389/fcimb.2015.00067      False
# 8    FU Berlin    2015  1160.25       10.5194/acp-15-6897-2015      False
# 9    FU Berlin    2015  1191.21   10.1371/journal.pone.0140050      False
# 10   FU Berlin    2015  1142.40       10.3389/fpsyg.2015.01137      False
# 11   FU Berlin    2015  1298.29       10.3389/fpsyg.2015.01661      False
# 13   FU Berlin    2015  1165.00              10.1038/srep11598      False
# 14   FU Berlin    2015  1386.35              10.1038/srep12681      False
# 16   FU Berlin    2015   892.50          10.4081/ejh.2015.2516      False
# ...

# %%
# %matplotlib inline

# %%
APCs["euro"].hist()

# %%
APCs["euro"].hist(bins=50, color="purple")
